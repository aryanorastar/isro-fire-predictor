# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🔥 Forest Fire Spread Prediction Demo\n",
    "\n",
    "This notebook demonstrates the end-to-end pipeline for forest fire spread prediction using the provided AI/ML modules."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Setup & Imports"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import os\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "from src.preprocess import DataPreprocessor\n",
    "from src.train import train\n",
    "from src.infer import FirePredictor\n",
    "from src.utils import load_config\n"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Data Preprocessing (Synthetic Example)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "preprocessor = DataPreprocessor()\n",
    "region = 'uttarakhand'\n",
    "date = '2024-01-15'\n",
    "data = preprocessor.prepare_model_input(region, date)\n",
    "print('Input tensor shape:', data['input_tensor'].shape)\n",
    "# Save for training\n",
    "preprocessor.save_preprocessed_data(data, 'data/sample_preprocessed.npz')"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Model Training (Quick Demo)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# This will train on the synthetic sample. For real use, add more .npz files to data/\n",
    "train()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Inference & Visualization"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "predictor = FirePredictor()\n",
    "result = predictor.predict(region=region, date=date, time_window='24h')\n",
    "pred = np.array(result['prediction'])\n",
    "plt.figure(figsize=(8, 6))\n",
    "plt.imshow(pred, cmap='hot', interpolation='nearest')\n",
    "plt.title('Predicted Fire Spread Heatmap')\n",
    "plt.colorbar(label='Fire Probability')\n",
    "plt.show()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "---\n",
    "**End of Demo**\n",
    "\n",
    "- For more realistic results, preprocess and add more data samples.\n",
    "- Try different regions, dates, and model settings in `config.yaml`.\n",
    "- Use the Streamlit dashboard for interactive predictions."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# 🔥 Forest Fire Spread Prediction Demo\n",
#       8     "\n",
#       9     "This notebook demonstrates the end-to-end pipeline for forest fire spread prediction using the provided AI/ML modules."
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "markdown",
#      14    "metadata": {},
#      15    "source": [
#      16     "## 1. Setup & Imports"
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "code",
#      21    "metadata": {},
#      22    "source": [
#      23     "import os\n",
#      24     "import numpy as np\n",
#      25     "import matplotlib.pyplot as plt\n",
#      26     "from src.preprocess import DataPreprocessor\n",
#      27     "from src.train import train\n",
#      28     "from src.infer import FirePredictor\n",
#      29     "from src.utils import load_config\n"
#      30    ],
# ---> 31    "execution_count": null,
#      32    "outputs": []
#      33   },
#      34   {
#      35    "cell_type": "markdown",
#      36    "metadata": {},
#      37    "source": [
#      38     "## 2. Data Preprocessing (Synthetic Example)"
#      39    ]
#      40   },
#      41   {
#      42    "cell_type": "code",
#      43    "metadata": {},
#      44    "source": [
#      45     "preprocessor = DataPreprocessor()\n",
#      46     "region = 'uttarakhand'\n",
#      47     "date = '2024-01-15'\n",
#      48     "data = preprocessor.prepare_model_input(region, date)\n",
#      49     "print('Input tensor shape:', data['input_tensor'].shape)\n",
#      50     "# Save for training\n",
#      51     "preprocessor.save_preprocessed_data(data, 'data/sample_preprocessed.npz')"
#      52    ],
#      53    "execution_count": null,
#      54    "outputs": []
#      55   },
#      56   {
#      57    "cell_type": "markdown",
#      58    "metadata": {},
#      59    "source": [
#      60     "## 3. Model Training (Quick Demo)"
#      61    ]
#      62   },
#      63   {
#      64    "cell_type": "code",
#      65    "metadata": {},
#      66    "source": [
#      67     "# This will train on the synthetic sample. For real use, add more .npz files to data/\n",
#      68     "train()"
#      69    ],
#      70    "execution_count": null,
#      71    "outputs": []
#      72   },
#      73   {
#      74    "cell_type": "markdown",
#      75    "metadata": {},
#      76    "source": [
#      77     "## 4. Inference & Visualization"
#      78    ]
#      79   },
#      80   {
#      81    "cell_type": "code",
#      82    "metadata": {},
#      83    "source": [
#      84     "predictor = FirePredictor()\n",
#      85     "result = predictor.predict(region=region, date=date, time_window='24h')\n",
#      86     "pred = np.array(result['prediction'])\n",
#      87     "plt.figure(figsize=(8, 6))\n",
#      88     "plt.imshow(pred, cmap='hot', interpolation='nearest')\n",
#      89     "plt.title('Predicted Fire Spread Heatmap')\n",
#      90     "plt.colorbar(label='Fire Probability')\n",
#      91     "plt.show()"
#      92    ],
#      93    "execution_count": null,
#      94    "outputs": []
#      95   },
#      96   {
#      97    "cell_type": "markdown",
#      98    "metadata": {},
#      99    "source": [
#     100     "---\n",
#     101     "**End of Demo**\n",
#     102     "\n",
#     103     "- For more realistic results, preprocess and add more data samples.\n",
#     104     "- Try different regions, dates, and model settings in `config.yaml`.\n",
#     105     "- Use the Streamlit dashboard for interactive predictions."
#     106    ]
#     107   }
#     108  ],
#     109  "metadata": {
#     110   "kernelspec": {
#     111    "display_name": "Python 3",
#     112    "language": "python",
#     113    "name": "python3"
#     114   },
#     115   "language_info": {
#     116    "name": "python",
#     117    "version": "3.10"
#     118   }
#     119  },
#     120  "nbformat": 4,
#     121  "nbformat_minor": 2
#     122 }
#
# NameError: name 'null' is not defined
